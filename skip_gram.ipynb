# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as tud
from collections import Counter
import numpy as np
import random
import math
import pandas as pd
import scipy
import sklearn
from sklearn.metrics.pairwise import cosine_similarity
import utils

# %% [markdown]
# # 读取数据集

# %%
with open('text8.train.txt','r') as fin:
    text = fin.read()

# %%
def word_tokenize(text):
    return text.split()

words = text.split()

# %%
words[:10]
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 15304686
# Unique words: 240006

# %%
vocab = dict(Counter(words))
vocab
# Out:
# {'anarchism': 303,
#  'originated': 505,
#  'as': 119348,
#  'a': 293387,
#  'term': 6533,
#  'of': 537144,
#  'abuse': 531,
#  'first': 25760,
#  'used': 20455,
#  'against': 7640,
#  'early': 9129,
#  'working': 2054,
#  'class': 3111,
#  'radicals': 106,
#  'including': 8694,
#  'the': 959616,
#  'diggers': 25,
#  'english': 10582,
#  'revolution': 1862,
#  'and': 376233,
#  'sans': 54,
#  'culottes': 6,
#  'french': 7750,
#  'whilst': 442,
#  'is': 166132,
#  'still': 6664,
#  'in': 335477,
#  'pejorative': 104,
#  'way': 5793,
#  'to': 285950,
#  'describe': 1203,
#  'any': 10796,
#  'act': 3216,
#  'that': 99419,
#  'violent': 581,
#  'means': 3822,
#  'destroy': 423,
#  'organization': 2147,
#  'society': 3745,
#  'it': 66521,
#  'has': 34244,
#  'also': 40020,
#  'been': 22950,
#  'taken': 2795,
#  'up': 11199,
#  'positive': 1157,
#  'label': 549,
#  'by': 100994,
#  'self': 2614,
#  'defined': 2192,
#  'anarchists': 200,
#  'word': 5066,
#  'derived': 1533,
#  'from': 65835,
#  'greek': 4197,
#  'without': 5152,
#  'archons': 10,
#  'ruler': 542,
#  'chief': 1933,
#  'king': 6641,
#  'political': 6277,
#  'philosophy': 2598,
#  'belief': 1449,
#  'rulers': 631,
#  'are': 69591,
#  'unnecessary': 135,
#  'should': 4687,
#  'be': 55837,
#  'abolished': 368,
#  'although': 8386,
#  'there': 20628,
#  'differing': 206,
#  'interpretations': 357,
#  'what': 7750,
#  'this': 53314,
#  'refers': 1424,
#  'related': 3198,
#  'social': 3914,
#  'movements': 916,
#  'advocate': 313,
#  'elimination': 200,
#  'authoritarian': 168,
#  'institutions': 932,
#  'particularly': 2603,
#  'state': 11578,
#  'anarchy': 95,
#  'most': 23025,
#  'use': 12697,
#  'does': 4791,
#  'not': 40095,
#  'imply': 231,
#  'chaos': 309,
#  'nihilism': 33,
#  'or': 62715,
#  'anomie': 6,
#  'but': 32181,
#  'rather': 4205,
#  'harmonious': 26,
#  'anti': 2846,
#  'place': 4842,
#  'regarded': 1362,
#  'structures': 1026,
#  'coercive': 57,
#  'economic': 3937,
#  'relations': 2008,
#  'based': 7328,
#  'upon': 3434,
#  'voluntary': 247,
#  'association': 2023,
#  'autonomous': 358,
#  'individuals': 1453,
#  'mutual': 348,
#  'aid': 1006,
#  'governance': 160,
#  'while': 11191,
#  'easily': 1124,
#  'offer': 802,
#  'visions': 158,
#  'they': 26068,
#  'believe': 2186,
#  'truly': 366,
#  'free': 5158,
#  'however': 14351,
#  'ideas': 1660,
#  'about': 14110,
#  'how': 4266,
#  'an': 56020,
#  'anarchist': 328,
#  'might': 2959,
#  'work': 8599,
#  'vary': 706,
#  'considerably': 434,
#  'especially': 3757,
#  'with': 86114,
#  'respect': 902,
#  'economics': 869,
#  'disagreement': 150,
#  'brought': 2028,
#  'origins': 968,
#  'predecessors': 154,
#  'kropotkin': 31,
#  'others': 4682,
#  'argue': 969,
#  'before': 7927,
#  'recorded': 1543,
#  'history': 11517,
#  'human': 5642,
#  'was': 101525,
#  'organized': 877,
#  'on': 82176,
#  'principles': 1057,
#  'anthropologists': 150,
#  'follow': 1112,
#  'engels': 82,
#  'believing': 228,
#  'hunter': 371,
#  'gatherer': 32,
#  'bands': 686,
#  'were': 35195,
#  'egalitarian': 55,
#  'lacked': 187,
#  'division': 1798,
#  'labour': 1337,
#  'accumulated': 117,
#  'wealth': 647,
#  'decreed': 64,
#  'law': 6809,
#  'had': 25322,
#  'equal': 1444,
#  'access': 1712,
#  'resources': 1552,
#  'william': 3087,
#  'godwin': 74,
#  'organisation': 507,
#  'rothbard': 62,
#  'find': 2065,
#  'attitudes': 197,
#  'taoism': 61,
#  'ancient': 3217,
#  'china': 2944,
#  'found': 6424,
#  'similar': 4445,
#  'stoic': 40,
#  'zeno': 41,
#  'citium': 7,
#  'according': 4419,
#  'repudiated': 56,
#  'omnipotence': 20,
#  'its': 26523,
#  'intervention': 403,
#  'regimentation': 7,
#  'proclaimed': 392,
#  'sovereignty': 443,
#  'moral': 943,
#  'individual': 2482,
#  'anabaptists': 74,
#  'one': 363077,
#  'six': 89549,
#  'th': 12126,
#  'century': 9649,
#  'europe': 4625,
#  'sometimes': 5263,
#  'considered': 5440,
#  'religious': 3256,
#  'forerunners': 23,
#  'modern': 7044,
#  'bertrand': 168,
#  'russell': 678,
#  'his': 57430,
#  'western': 4459,
#  'writes': 352,
#  'all': 23731,
#  'since': 9664,
#  'held': 3755,
#  'good': 3631,
#  'man': 5179,
#  'will': 11445,
#  'guided': 271,
#  'at': 49447,
#  'every': 4011,
#  'moment': 583,
#  'holy': 1889,
#  'spirit': 1189,
#  'premise': 140,
#  'arrive': 207,
#  'communism': 505,
#  'true': 2705,
#  'levellers': 11,
#  'communistic': 7,
#  'movement': 3193,
#  'during': 13133,
#  'time': 18568,
#  'civil': 3059,
#  'war': 13167,
#  'some': 25445,
#  'era': 1856,
#  'mean': 1515,
#  'something': 1568,
#  'other': 29299,
#  'than': 17129,
#  'louis': 1648,
#  'armand': 63,
#  'baron': 328,
#  'de': 7012,
#  'lahontan': 2,
#  'nouveaux': 12,
#  'voyages': 97,
#  'dans': 32,
#  'l': 4842,
#  'am': 1314,
#  'rique': 5,
#  'septentrionale': 2,
#  'seven': 88376,
#  'zero': 234010,
#  'three': 101679,
#  'where': 11121,
#  'he': 49171,
#  'described': 2435,
#  'indigenous': 590,
#  'american': 17548,
#  'which': 49662,
#  'no': 14736,
#  'laws': 2258,
#  'prisons': 67,
#  'priests': 383,
#  'private': 1871,
#  'property': 1769,
#  'being': 10829,
#  'libertarian': 223,
#  'leader': 2229,
#  'indian': 2073,
#  'repeatedly': 358,
#  'stated': 1276,
#  'so': 11613,
#  'ancestors': 275,
#  'nine': 219583,
#  'thick': 253,
#  'published': 4079,
#  'enquiry': 54,
#  'concerning': 685,
#  'justice': 1238,
#  'did': 5788,
#  'many': 21810,
#  'later': 9852,
#  'have': 36098,
#  'book': 6515,
#  'major': 6758,
#  'text': 2848,
#  'founder': 894,
#  'philosophical': 879,
#  'point': 5613,
#  'yet': 2104,
#  'existed': 677,
#  'anarchiste': 2,
#  'known': 13067,
#  'mainly': 1506,
#  'insult': 63,
#  'hurled': 21,
#  'bourgeois': 86,
#  'girondins': 6,
#  'more': 23810,
#  'radical': 692,
#  'elements': 2475,
#  'labelled': 128,
#  'pierre': 540,
#  'joseph': 1570,
#  'proudhon': 72,
#  'commonly': 2377,
#  'wasn': 251,
#  't': 7646,
#  'until': 6661,
#  'eight': 110358,
#  'four': 95710,
#  'adopted': 1614,
#  'description': 993,
#  'for': 106897,
#  'reason': 1758,
#  'claim': 1871,
#  'theory': 5870,
#  'answers': 269,
#  'famous': 3357,
#  'accusation': 85,
#  'theft': 197,
#  'opposed': 1184,
#  'institution': 552,
#  'propri': 5,
#  'owners': 440,
#  'complete': 2314,
#  'rights': 3191,
#  'their': 28607,
#  'wish': 431,
#  'such': 22095,
#  'exploiting': 56,
#  'workers': 1059,
#  'profit': 554,
#  'supported': 1381,
#  'called': 12716,
#  'possession': 501,
#  'can': 23247,
#  'limited': 2005,
#  'capital': 2809,
#  'goods': 919,
#  'accordance': 247,
#  'equality': 285,
#  's': 105101,
#  'vision': 631,
#  'mutualism': 22,
#  'mutuellisme': 1,
#  'involved': 1686,
#  'exchange': 1193,
#  'economy': 2789,
#  'groups': 4243,
#  'could': 7416,
#  'trade': 2826,
#  'products': 1850,
#  'labor': 1287,
#  'using': 5750,
#  'notes': 1511,
#  'represented': 1170,
#  'amount': 1764,
#  'production': 3190,
#  'would': 15611,
#  'ensure': 562,
#  'freely': 350,
#  'join': 640,
#  'together': 2999,
#  'co': 2087,
#  'operative': 104,
#  'workshops': 44,
#  'interest': 1993,
#  'bank': 1588,
#  'set': 6789,
#  'provide': 2028,
#  'everyone': 492,
#  'influential': 833,
#  'within': 5650,
#  'followers': 510,
#  'active': 1586,
#  'france': 4280,
#  'complex': 2381,
#  'developed': 3828,
#  'number': 10282,
#  'works': 4364,
#  'over': 13639,
#  'lifetime': 437,
#  'detailed': 774,
#  'discussion': 1035,
#  'see': 17453,
#  'here': 2466,
#  'max': 486,
#  'stirner': 27,
#  'egoism': 62,
#  'ego': 108,
#  'own': 6348,
#  'argued': 1130,
#  'accepted': 1570,
#  'notion': 627,
#  'right': 5304,
#  'natural': 3624,
#  'general': 7888,
#  'very': 7974,
#  'mere': 316,
#  'illusions': 38,
#  'ghosts': 135,
#  'mind': 1480,
#  'saying': 828,
#  'reality': 928,
#  'advocated': 264,
#  'form': 8257,
#  'amoralism': 2,
#  'unite': 123,
#  'associations': 241,
#  'egoists': 8,
#  'only': 17607,
#  'when': 18743,
#  'do': 7134,
#  'him': 9775,
#  'simply': 2214,
#  'comes': 1391,
#  'through': 9388,
#  'whoever': 78,
#  'knows': 259,
#  'take': 3720,
#  'defend': 379,
#  'thing': 931,
#  'belongs': 264,
#  'i': 16123,
#  'my': 2469,
#  'power': 6803,
#  'long': 6779,
#  'assert': 220,
#  'myself': 130,
#  'holder': 181,
#  'proprietor': 13,
#  'never': 3787,
#  'himself': 3586,
#  'egoist': 11,
#  'nevertheless': 791,
#  'individualistically': 1,
#  'inclined': 111,
#  'thought': 2919,
#  'diverse': 475,
#  'individualist': 121,
#  'benjamin': 493,
#  'tucker': 128,
#  'two': 170527,
#  'five': 102330,
#  'josiah': 106,
#  'warren': 246,
#  'participated': 273,
#  'communitarian': 7,
#  'experiment': 649,
#  'headed': 516,
#  'robert': 2417,
#  'owen': 171,
#  'new': 21235,
#  'harmony': 282,
#  'failed': 1195,
#  'few': 4583,
#  'years': 13318,
#  'amidst': 48,
#  'much': 8005,
#  'internal': 1372,
#  'conflict': 1346,
#  'blamed': 171,
#  'community': 3236,
#  'failure': 886,
#  'lack': 1413,
#  'proceeded': 180,
#  'organise': 40,
#  'experimenal': 1,
#  'communities': 1111,
#  'respected': 244,
#  'utopia': 58,
#  'times': 5036,
#  'wrote': 2692,
#  'peaceful': 250,
#  'revolutionist': 5,
#  'noted': 1405,
#  'periodical': 53,
#  'ever': 2212,
#  'says': 1042,
#  'expound': 9,
#  'formulate': 53,
#  'doctrine': 930,
#  'now': 7438,
#  'liberty': 521,
#  'xiv': 208,
#  'december': 3123,
#  'became': 8613,
#  'interested': 452,
#  'meeting': 914,
#  'b': 14783,
#  'greene': 81,
#  'edited': 610,
#  'august': 2730,
#  'april': 2716,
#  'widely': 2271,
#  'finest': 184,
#  'issued': 799,
#  'language': 8550,
#  'conception': 330,
#  'incorporated': 645,
#  'variety': 1679,
#  'theorists': 210,
#  'banking': 307,
#  'cost': 1476,
#  'limit': 754,
#  'price': 1016,
#  'heterodox': 19,
#  'value': 2698,
#  'market': 2472,
#  'herbert': 474,
#  'spencer': 177,
#  'freedom': 1518,
#  'strongly': 773,
#  'product': 1660,
#  'her': 9751,
#  'believed': 2093,
#  'trading': 628,
#  'system': 11809,
#  'abundance': 138,
#  'competition': 942,
#  'eliminate': 214,
#  'profits': 236,
#  'received': 2345,
#  'full': 3351,
#  'individualists': 38,
#  'included': 2877,
#  'lysander': 26,
#  'spooner': 30,
#  'stephen': 688,
#  'pearl': 261,
#  'andrews': 122,
#  'victor': 364,
#  'yarros': 4,
#  'international': 6560,
#  'mikhail': 177,
#  'bakunin': 46,
#  'harsh': 221,
#  'reaction': 1079,
#  'followed': 2302,
#  'revolutions': 122,
#  'twenty': 991,
#  'workingmen': 6,
#  'united': 12965,
#  'european': 5258,
#  'revolutionary': 860,
#  'currents': 181,
#  'due': 5429,
#  'genuine': 204,
#  'links': 7497,
#  'signficiant': 1,
#  'start': 1428,
#  'karl': 570,
#  'marx': 538,
#  'leading': 1920,
#  'figure': 1301,
#  'elected': 2206,
#  'succeeding': 100,
#  'council': 3167,
#  'objections': 135,
#  'came': 3381,
#  'mutualists': 4,
#  'who': 21795,
#  'statism': 17,
#  'shortly': 886,
#  'after': 19079,
#  'joined': 1320,
#  'polarised': 10,
#  'into': 18431,
#  'camps': 506,
#  'respective': 311,
#  'figureheads': 2,
#  'clearest': 16,
#  'difference': 1253,
#  'between': 14309,
#  'strategy': 701,
#  'around': 5901,
#  'favoured': 143,
#  'words': 3521,
#  'direct': 1809,
#  'economical': 86,
#  'struggle': 572,
#  'capitalism': 604,
#  'interfering': 47,
#  'parliamentary': 638,
#  'agitation': 54,
#  'focused': 492,
#  'activity': 1282,
#  'characterised': 135,
#  'predicted': 289,
#  'if': 13176,
#  'marxist': 295,
#  'party': 6207,
#  'gained': 1066,
#  'leaders': 1282,
#  'end': 6418,
#  'bad': 867,
#  'ruling': 470,
#  'fought': 735,
#  'climaxed': 6,
#  'final': 2814,
#  'split': 860,
#  'hague': 93,
#  'congress': 1670,
#  'often': 11774,
#  'cited': 526,
#  'origin': 1873,
#  'marxists': 96,
#  'democratic': 1662,
#  'socialism': 357,
#  'distinct': 1091,
#  'organisations': 312,
#  'rival': 409,
#  'internationals': 21,
#  'peter': 1727,
#  'both': 10623,
#  'associating': 42,
#  'moved': 1902,
#  'away': 2096,
#  'thinking': 563,
#  'collectivism': 38,
#  'embraced': 131,
#  'communist': 1444,
#  'concepts': 935,
#  'communists': 381,
#  'owned': 846,
#  'collectively': 225,
#  'distributed': 696,
#  'need': 1976,
#  'd': 14503,
#  'jacque': 4,
#  'person': 3550,
#  'unlike': 1218,
#  'worker': 266,
#  'satisfaction': 106,
#  'needs': 860,
#  'whatever': 450,
#  'may': 17252,
#  'nature': 2764,
#  'announced': 1104,
#  'us': 5104,
#  'journal': 1056,
#  'le': 1171,
#  'libertaire': 1,
#  'seen': 3428,
#  'important': 5308,
#  'theorist': 79,
#  'outlined': 123,
#  'conquest': 541,
#  'bread': 317,
#  'fields': 1191,
#  'factories': 158,
#  'felt': 817,
#  'operation': 1592,
#  'beneficial': 167,
#  'illustrated': 344,
#  'factor': 846,
#  'evolution': 1393,
#  'subsequent': 941,
#  'include': 5863,
#  'emma': 158,
#  'goldman': 108,
#  'alexander': 1820,
#  'berkman': 21,
#  'anarcho': 274,
#  'syndicalist': 22,
#  'below': 2566,
#  'saw': 1865,
#  'objective': 354,
#  'isaac': 458,
#  'puente': 6,
#  'comunismo': 2,
#  'libertario': 3,
#  'spanish': 2709,
#  'cnt': 21,
#  'manifesto': 173,
#  'post': 2172,
#  'disliked': 72,
#  'merging': 99,
#  'several': 8225,
#  'maintained': 712,
#  'abolition': 165,
#  'consistent': 483,
#  'example': 8689,
#  'professing': 13,
#  'publishing': 733,
#  'pseudo': 149,
#  'propaganda': 335,
#  'deed': 73,
#  'johann': 435,
#  'outspoken': 79,
#  'violence': 947,
#  'portrayed': 410,
#  'dangerous': 624,
#  'high': 7512,
#  'profile': 545,
#  'acts': 1415,
#  'riots': 191,
#  'assassinations': 55,
#  'insurrections': 12,
#  'terrorism': 286,
#  'revolutionaries': 92,
#  'late': 4011,
#  'encouraged': 497,
#  'bombings': 112,
#  'heads': 630,
#  'further': 3743,
#  'actions': 1069,
#  'advocates': 358,
#  'said': 4051,
#  'existing': 972,
#  'quickest': 19,
#  'radically': 106,
#  'overthrown': 123,
#  'annihilation': 57,
#  'exponents': 53,
#  'therefore': 2533,
#  'massacres': 77,
#  'enemies': 518,
#  'people': 13304,
#  'must': 4510,
#  'motion': 1377,
#  'preferred': 584,
#  'method': 2205,
#  'dynamite': 80,
#  'earned': 439,
#  'moniker': 49,
#  'dynamost': 1,
#  'consensus': 378,
#  'legitimacy': 136,
#  'utility': 259,
#  'errico': 8,
#  'malatesta': 13,
#  'necessary': 1391,
#  'desirable': 157,
#  'force': 4321,
#  'settings': 270,
#  'same': 8815,
#  'denounced': 142,
#  'refuted': 48,
#  'nechaev': 1,
#  'identified': 945,
#  'pacifist': 71,
#  'nonviolence': 21,
#  'leo': 478,
#  'tolstoy': 95,
#  'whose': 2628,
#  'viewed': 740,
#  'christian': 4011,
#  'notable': 1705,
#  'exponent': 69,
#  'nonviolent': 20,
#  'resistance': 865,
#  'red': 3431,
#  'black': 4042,
#  'flag': 1204,
#  'coming': 838,
#  'experience': 1588,
#  'associated': 2145,
#  'syndicalism': 29,
#  'seeking': 428,
#  'overthrow': 179,
#  'institute': 1593,
#  'controlled': 1097,
#  'pursued': 248,
#  'industrial': 1377,
#  'strike': 644,
#  'primary': 1800,
#  'syndicalists': 20,
#  'though': 5780,
#  'repression': 108,
#  'reemerged': 5,
#  'influencing': 77,
#  'bourses': 4,
#  'travails': 4,
#  'unions': 385,
#  'conf': 25,
#  'ration': 59,
#  'g': 7991,
#  'n': 7582,
#  'rale': 33,
#  'du': 553,
#  'travail': 6,
#  'confederation': 335,
#  'cgt': 7,
#  'formed': 2391,
#  'emile': 71,
#  'pataud': 1,
#  'pouget': 1,
#  'writing': 2179,
#  'developing': 730,
#  'appeal': 655,
#  'bolshevism': 26,
#  'style': 3075,
#  'significant': 2301,
#  'prior': 1255,
#  'remained': 1907,
#  'spain': 1900,
#  'mid': 1698,
#  'world': 16099,
#  'iww': 13,
#  'founded': 2009,
#  'espoused': 60,
#  'unionism': 22,
#  'sought': 782,
#  'usher': 57,
#  'stateless': 57,
#  'members': 5108,
#  'support': 4141,
#  'explicitly': 427,
#  'rank': 612,
#  'file': 1544,
#  'democracy': 942,
#  'embodying': 14,
#  'inspired': 1010,
#  'anglophone': 38,
#  'reads': 194,
#  'don': 1660,
#  'let': 1067,
#  'politicians': 436,
#  'rule': 2614,
#  'our': 2569,
#  'lives': 1011,
#  'you': 6088,
#  'vote': 1259,
#  'decide': 356,
#  'allow': 1764,
#  'unity': 479,
#  'action': 2487,
#  'management': 1263,
#  'union': 4697,
#  'federations': 39,
#  'successful': 1819,
#  'confederaci': 8,
#  'nacional': 113,
#  'del': 715,
#  'trabajo': 7,
#  'national': 8114,
#  'politics': 1879,
#  'membership': 702,
#  'million': 3898,
#  'played': 3202,
#  'role': 3305,
#  'like': 8881,
#  'ricardo': 95,
#  'flores': 55,
#  'mag': 38,
#  'key': 2339,
#  'figures': 1032,
#  'mexican': 451,
#  'latin': 3086,
#  'influenced': 1307,
#  'extending': 283,
#  'zapatista': 18,
#  'rebellion': 533,
#  'factory': 399,
#  'occupation': 705,
#  'argentina': 572,
#  'berlin': 1227,
#  'successor': 627,
#  'contemporary': 1272,
#  'continues': 906,
#  'minor': 1618,
#  'socities': 1,
#  'smaller': 1746,
#  'largest': 3370,
#  'organised': 231,
#  'today': 3785,
#  'claims': 1723,
#  'paid': 742,
#  'votes': 571,
#  'syndical': 1,
#  'elections': 1676,
#  'solidarity': 102,
#  'alliance': 801,
#  'uk': 2797,
#  'federation': 669,
#  'unionist': 48,
#  'exists': 1118,
#  'claiming': 451,
#  'critics': 1251,
#  'workerist': 1,
#  'fail': 266,
#  'deal': 1165,
#  'life': 9063,
#  'outside': 2320,
#  'leftist': 87,
#  'bob': 950,
#  'oppressive': 70,
#  'workplace': 63,
#  'uphold': 42,
#  'russian': 2578,
#  'seismic': 45,
#  'event': 1598,
#  'development': 4215,
#  'alongside': 355,
#  'bolsheviks': 147,
#  'february': 2483,
#  'october': 2745,
#  'initially': 1093,
#  'supporting': 638,
#  'bolshevik': 149,
#  'coup': 646,
#  'soon': 2134,
#  'turned': 1240,
#  'left': 5634,
#  'wing': 1054,
#  'opposition': 1260,
#  'culminated': 119,
#  'kronstadt': 11,
#  'central': 4626,
#  'russia': 2048,
#  'imprisoned': 238,
#  'driven': 544,
#  'underground': 641,
#  'victorious': 135,
#  'ukraine': 330,
#  'whites': 142,
#  'makhnovshchina': 1,
#  'peasant': 140,
#  'army': 3932,
#  'led': 4645,
#  'nestor': 25,
#  'makhno': 8,
#  'expelled': 272,
#  'leaving': 949,
#  'amongst': 568,
#  'those': 7517,
#  'agitating': 9,
#  'response': 1436,
#  'policy': 2053,
#  'suppression': 160,
#  'uprising': 317,
#  'classic': 1063,
#  'accounts': 751,
#  'experiences': 467,
#  'aiming': 90,
#  'expose': 65,
#  'control': 4477,
#  'them': 10311,
#  'predictions': 157,
#  'consequences': 423,
#  'proved': 1102,
#  'too': 2492,
#  'victory': 1076,
#  'resulting': 1181,
#  'serious': 1130,
#  'damage': 999,
#  'internationally': 274,
#  'activists': 230,
#  'success': 1948,
#  'setting': 779,
#  'parties': 1881,
#  'grew': 903,
#  'expense': 250,
#  'socialist': 697,
#  'began': 4536,
#  'realign': 7,
#  'themselves': 2600,
#  'towards': 1814,
#  'paris': 1562,
#  'dielo': 1,
#  'truda': 1,
#  'group': 6659,
#  'exiles': 71,
#  'concluded': 419,
#  'needed': 1293,
#  'develop': 966,
#  'forms': 3081,
#  'organisational': 25,
#  'platform': 546,
#  'inspire': 67,
#  'theoretical': 551,
#  'tactical': 215,
#  'collective': 415,
#  'responsibility': 520,
#  'federalism': 60,
#  'platformist': 2,
#  'ireland': 2212,
#  'north': 6625,
#  'eastern': 2997,
#  'northeastern': 170,
#  'states': 13412,
#  'bordering': 108,
#  'canada': 3106,
#  'fight': 902,
#  'fascism': 285,
#  'construct': 290,
#  'armoured': 204,
#  'cars': 805,
#  'fascists': 48,
#  'collectivised': 4,
#  'familiar': 510,
#  'dynamics': 237,
#  'transformed': 291,
#  'rise': 1508,
#  'cases': 2595,
#  'faced': 506,
#  ...}

# %% [markdown]
# # 二次采样

# %%
np.random.seed(123)
def sub_sampling(vocab, threshold):
    word_counter = Counter(vocab)
    total_count = len(vocab)
    freq= {word: count/total_count for word, count in vocab.items()}
    p_drop ={word:(1-np.sqrt(threshold/ freq[word])) for word in word_counter}
    trained_words = {word:vocab[word] for word in vocab if p_drop[word]<np.random.random()}
    return trained_words

train_words = sub_sampling(vocab, threshold= 1e-4)

# %%
train_words['<unk>'] = np.sum(list(vocab.values())) - np.sum(list(train_words.values()))
train_words
# Out:
# {'abuse': 531,
#  'diggers': 25,
#  'sans': 54,
#  'culottes': 6,
#  'society': 3745,
#  'by': 100994,
#  'archons': 10,
#  'differing': 206,
#  'authoritarian': 168,
#  'anarchy': 95,
#  'imply': 231,
#  'chaos': 309,
#  'nihilism': 33,
#  'anomie': 6,
#  'harmonious': 26,
#  'governance': 160,
#  'believe': 2186,
#  'truly': 366,
#  'how': 4266,
#  'respect': 902,
#  'argue': 969,
#  'anthropologists': 150,
#  'gatherer': 32,
#  'bands': 686,
#  'egalitarian': 55,
#  'decreed': 64,
#  'godwin': 74,
#  'organisation': 507,
#  'rothbard': 62,
#  'zeno': 41,
#  'citium': 7,
#  'omnipotence': 20,
#  'regimentation': 7,
#  'anabaptists': 74,
#  'religious': 3256,
#  'forerunners': 23,
#  'writes': 352,
#  'holy': 1889,
#  'premise': 140,
#  'arrive': 207,
#  'levellers': 11,
#  'communistic': 7,
#  'something': 1568,
#  'armand': 63,
#  'baron': 328,
#  'lahontan': 2,
#  'nouveaux': 12,
#  'voyages': 97,
#  'dans': 32,
#  'rique': 5,
#  'septentrionale': 2,
#  'where': 11121,
#  'laws': 2258,
#  'enquiry': 54,
#  'justice': 1238,
#  'major': 6758,
#  'philosophical': 879,
#  'anarchiste': 2,
#  'mainly': 1506,
#  'insult': 63,
#  'hurled': 21,
#  'girondins': 6,
#  'claim': 1871,
#  'accusation': 85,
#  'theft': 197,
#  'propri': 5,
#  'exploiting': 56,
#  'capital': 2809,
#  'goods': 919,
#  'mutualism': 22,
#  'mutuellisme': 1,
#  'involved': 1686,
#  'groups': 4243,
#  'workshops': 44,
#  'bank': 1588,
#  'followers': 510,
#  'number': 10282,
#  'stirner': 27,
#  'ego': 108,
#  'illusions': 38,
#  'mind': 1480,
#  'amoralism': 2,
#  'egoists': 8,
#  'whoever': 78,
#  'take': 3720,
#  'defend': 379,
#  'belongs': 264,
#  'i': 16123,
#  'proprietor': 13,
#  'egoist': 11,
#  'individualistically': 1,
#  'individualist': 121,
#  'communitarian': 7,
#  'experiment': 649,
#  'owen': 171,
#  'amidst': 48,
#  'blamed': 171,
#  'organise': 40,
#  'experimenal': 1,
#  'times': 5036,
#  'revolutionist': 5,
#  'expound': 9,
#  'formulate': 53,
#  'meeting': 914,
#  'august': 2730,
#  'widely': 2271,
#  'incorporated': 645,
#  'theorists': 210,
#  'price': 1016,
#  'heterodox': 19,
#  'herbert': 474,
#  'competition': 942,
#  'individualists': 38,
#  'lysander': 26,
#  'stephen': 688,
#  'yarros': 4,
#  'bakunin': 46,
#  'harsh': 221,
#  'workingmen': 6,
#  'signficiant': 1,
#  'marx': 538,
#  'mutualists': 4,
#  'statism': 17,
#  'polarised': 10,
#  'figureheads': 2,
#  'clearest': 16,
#  'difference': 1253,
#  'strategy': 701,
#  'favoured': 143,
#  'economical': 86,
#  'interfering': 47,
#  'agitation': 54,
#  'focused': 492,
#  'climaxed': 6,
#  'final': 2814,
#  'split': 860,
#  'organisations': 312,
#  'internationals': 21,
#  'associating': 42,
#  'away': 2096,
#  'collectivism': 38,
#  'embraced': 131,
#  'communist': 1444,
#  'jacque': 4,
#  'person': 3550,
#  'needs': 860,
#  'announced': 1104,
#  'us': 5104,
#  'libertaire': 1,
#  'theorist': 79,
#  'factories': 158,
#  'include': 5863,
#  'goldman': 108,
#  'berkman': 21,
#  'syndicalist': 22,
#  'puente': 6,
#  'comunismo': 2,
#  'libertario': 3,
#  'cnt': 21,
#  'disliked': 72,
#  'merging': 99,
#  'professing': 13,
#  'dangerous': 624,
#  'high': 7512,
#  'riots': 191,
#  'assassinations': 55,
#  'insurrections': 12,
#  'terrorism': 286,
#  'bombings': 112,
#  'heads': 630,
#  'quickest': 19,
#  'radically': 106,
#  'overthrown': 123,
#  'exponents': 53,
#  'earned': 439,
#  'dynamost': 1,
#  'legitimacy': 136,
#  'errico': 8,
#  'malatesta': 13,
#  'necessary': 1391,
#  'desirable': 157,
#  'denounced': 142,
#  'refuted': 48,
#  'nechaev': 1,
#  'pacifist': 71,
#  'nonviolence': 21,
#  'leo': 478,
#  'tolstoy': 95,
#  'whose': 2628,
#  'nonviolent': 20,
#  'syndicalism': 29,
#  'overthrow': 179,
#  'industrial': 1377,
#  'syndicalists': 20,
#  'reemerged': 5,
#  'influencing': 77,
#  'bourses': 4,
#  'travails': 4,
#  'conf': 25,
#  'ration': 59,
#  'travail': 6,
#  'confederation': 335,
#  'cgt': 7,
#  'pataud': 1,
#  'pouget': 1,
#  'bolshevism': 26,
#  'iww': 13,
#  'espoused': 60,
#  'unionism': 22,
#  'usher': 57,
#  'stateless': 57,
#  'file': 1544,
#  'embodying': 14,
#  'anglophone': 38,
#  'reads': 194,
#  'our': 2569,
#  'unity': 479,
#  'management': 1263,
#  'federations': 39,
#  'confederaci': 8,
#  'trabajo': 7,
#  'role': 3305,
#  'mag': 38,
#  'mexican': 451,
#  'extending': 283,
#  'zapatista': 18,
#  'argentina': 572,
#  'successor': 627,
#  'socities': 1,
#  'organised': 231,
#  'syndical': 1,
#  'unionist': 48,
#  'workerist': 1,
#  'oppressive': 70,
#  'workplace': 63,
#  'uphold': 42,
#  'alongside': 355,
#  'coup': 646,
#  'kronstadt': 11,
#  'imprisoned': 238,
#  'underground': 641,
#  'victorious': 135,
#  'makhnovshchina': 1,
#  'nestor': 25,
#  'makhno': 8,
#  'amongst': 568,
#  'agitating': 9,
#  'predictions': 157,
#  'success': 1948,
#  'parties': 1881,
#  'realign': 7,
#  'dielo': 1,
#  'truda': 1,
#  'exiles': 71,
#  'organisational': 25,
#  'inspire': 67,
#  'federalism': 60,
#  'platformist': 2,
#  'fascism': 285,
#  'fascists': 48,
#  'collectivised': 4,
#  'fronts': 58,
#  'reformist': 37,
#  'luigi': 88,
#  'fabbri': 2,
#  'imaginable': 21,
#  'represents': 768,
#  'utmost': 37,
#  'glorification': 14,
#  'principle': 1165,
#  'divided': 1736,
#  'abstention': 10,
#  'bring': 881,
#  'reponse': 2,
#  'armed': 1132,
#  'militias': 70,
#  'barcelona': 258,
#  'collectivized': 9,
#  'stalinists': 5,
#  'entering': 377,
#  'stalinist': 51,
#  'collectives': 16,
#  'fighting': 947,
#  'germany': 4109,
#  'militant': 143,
#  'combating': 29,
#  'relying': 106,
#  'racist': 119,
#  'antifa': 3,
#  'tends': 402,
#  'religiousity': 1,
#  'compatibility': 187,
#  'anarchistic': 10,
#  'corrupted': 59,
#  'declared': 1152,
#  'directive': 78,
#  'cheek': 74,
#  'pacifists': 12,
#  'resist': 187,
#  'vegan': 20,
#  'exhibits': 121,
#  'obey': 125,
#  'utterly': 78,
#  'certain': 3374,
#  'anabaptist': 56,
#  'sixteenth': 114,
#  'emulate': 69,
#  'capable': 764,
#  'obediance': 1,
#  'indeed': 1190,
#  'ungodly': 9,
#  'hutterites': 13,
#  'beginnings': 152,
#  'stabalised': 1,
#  'strands': 126,
#  'tai': 105,
#  'xu': 24,
#  'neopaganism': 24,
#  'decentralized': 56,
#  'starhawk': 3,
#  'activism': 104,
#  'feminism': 235,
#  'ricourt': 1,
#  'juliette': 21,
#  'mysogyny': 1,
#  'anarcha': 12,
#  'espouses': 13,
#  'patriarchy': 31,
#  'explicit': 297,
#  'wave': 871,
#  'feminist': 287,
#  'manifestation': 102,
#  'thus': 4830,
#  'oppression': 113,
#  'conclude': 150,
#  'primitivists': 4,
#  'roles': 560,
#  'primitivism': 14,
#  'addresses': 375,
#  'concerns': 610,
#  'eco': 63,
#  'voltairine': 4,
#  'cleyre': 6,
#  'wollstonecraft': 15,
#  'proto': 365,
#  'precursor': 177,
#  'philosophies': 145,
#  'explains': 336,
#  'miss': 268,
#  'she': 6625,
#  'proper': 871,
#  'annihilated': 38,
#  'supplant': 22,
#  'broader': 191,
#  'mcelroy': 13,
#  'predominantly': 333,
#  'branches': 600,
#  'recognise': 110,
#  'liberalism': 402,
#  'austrian': 949,
#  'germinal': 9,
#  'capitalist': 316,
#  'defines': 335,
#  'terms': 3182,
#  'competiting': 3,
#  'contractarianism': 2,
#  'narveson': 1,
#  'minarchists': 4,
#  'ayn': 91,
#  'rand': 276,
#  'nozick': 16,
#  'hart': 180,
#  'raico': 2,
#  'gustave': 95,
#  'auberon': 5,
#  'debate': 1099,
#  'embraces': 33,
#  'biodiversity': 151,
#  'sustainability': 33,
#  'importance': 985,
#  'ecofeminism': 2,
#  'involves': 758,
#  'agricultural': 797,
#  'luddites': 32,
#  'reclaim': 46,
#  'zerzan': 5,
#  'primitive': 318,
#  'societies': 739,
#  'offshoots': 29,
#  'syncretic': 18,
#  'formet': 1,
#  'schools': 1686,
#  'listed': 702,
#  'hakim': 25,
#  'bey': 17,
#  'distance': 1280,
#  'liberals': 367,
#  'etc': 1906,
#  'weakened': 193,
#  'attachment': 127,
#  'contrary': 475,
#  'milieu': 29,
#  'generalizations': 61,
#  'shuns': 3,
#  'favor': 641,
#  'crimethinc': 2,
#  'magazine': 1503,
#  'desire': 563,
#  'editor': 724,
#  'jason': 246,
#  'mcquinn': 1,
#  'infoshop': 4,
#  'leftism': 10,
#  'ws': 7,
#  'structuralism': 44,
#  'postanarchism': 2,
#  'saul': 217,
#  'receiving': 461,
#  'lacan': 106,
#  'poststructuralist': 8,
#  'autonomism': 1,
#  'situationism': 4,
#  'zapatismo': 1,
#  'rejects': 138,
#  'coherent': 122,
#  'doctrines': 245,
#  'certainty': 107,
#  'rubric': 9,
#  'thinkers': 191,
#  'gilles': 59,
#  'deleuze': 92,
#  'lix': 48,
#  'guattari': 30,
#  'clearinghouse': 19,
#  'insurrectionary': 7,
#  'formal': 1250,
#  'affinity': 126,
#  'struggles': 141,
#  'organizations': 1115,
#  'exploited': 148,
#  'wolfi': 1,
#  'landstreicher': 1,
#  'bonanno': 2,
#  'willful': 14,
#  'disobedience': 41,
#  'killing': 909,
#  'unconnected': 32,
#  'posited': 44,
#  'illegitimate': 152,
#  'position': 3052,
#  'graeber': 1,
#  'andrej': 5,
#  'grubacic': 1,
#  'decentralisation': 9,
#  'crucially': 15,
#  'rejection': 232,
#  'justifies': 24,
#  'imposing': 95,
#  'regulating': 93,
#  'minimized': 26,
#  'fair': 736,
#  'establishment': 653,
#  'create': 1582,
#  'monopoly': 306,
#  'interests': 742,
#  'criminality': 15,
#  'opposes': 78,
#  'subjugation': 22,
#  'color': 1904,
#  'hierarchical': 126,
#  'ashanti': 23,
#  'alston': 23,
#  'lorenzo': 101,
#  'komboa': 1,
#  'ervin': 4,
#  'mbah': 1,
#  'thoughts': 258,
#  'view': 3198,
#  'adherents': 176,
#  'groupings': 65,
#  'confronting': 32,
#  'agitators': 6,
#  'chiapas': 47,
#  'proclivities': 5,
#  'neocolonialism': 7,
#  'factions': 244,
#  'imperialism': 193,
#  'parallel': 836,
#  'outposts': 48,
#  'infoshops': 2,
#  'schooling': 61,
#  'arbitration': 146,
#  'shell': 479,
#  'recent': 2699,
#  'developments': 426,
#  'conceivable': 39,
#  'cyber': 53,
#  'indymedia': 12,
#  'authoritarianism': 39,
#  'crypto': 38,
#  'cypherpunk': 2,
#  'pacifism': 34,
#  'inherent': 224,
#  'consolidate': 67,
#  'domestically': 41,
#  'subscribe': 38,
#  'randolph': 61,
#  'bourne': 33,
#  'parliamentarianism': 1,
#  'ethos': 23,
#  'condoning': 2,
#  'voluntaryism': 2,
#  'emphasizes': 115,
#  'tending': 48,
#  'garden': 568,
#  'ballots': 54,
#  'bullets': 119,
#  'explained': 587,
#  'smith': 1588,
#  'oxymoron': 10,
#  'peacott': 3,
#  'woodworth': 6,
#  'sectarianism': 8,
#  'sectarian': 48,
#  'interact': 188,
#  'panarchists': 1,
#  'coexist': 28,
#  'interaction': 504,
#  'coalition': 672,
#  'least': 2913,
#  'purposes': 842,
#  'criticisms': 294,
#  'frederick': 548,
#  'criticsed': 1,
#  'imposes': 44,
#  'bayonets': 9,
#  'vain': 73,
#  'reactionists': 1,
#  'utopianism': 4,
#  'unfeasible': 4,
#  'plain': 503,
#  'nice': 183,
#  'landauer': 4,
#  'criticizes': 30,
#  'unrealistically': 5,
#  'lesser': 490,
#  'repressive': 60,
#  'ill': 478,
#  'intentions': 140,
#  'absurdity': 23,
#  'privately': 176,
#  'proudly': 29,
#  'characterization': 87,
#  'expression': 838,
#  'petite': 21,
#  'bourgeoisie': 41,
#  'lumpenproletariat': 2,
#  'plekhanov': 15,
#  'spoilt': 2,
#  'dilettantes': 1,
#  'relation': 829,
#  'protesters': 44,
#  'tacit': 31,
#  'situationists': 1,
#  'tacitly': 17,
#  'statist': 33,
#  'bureaucratic': 66,
#  'sexist': 42,
#  'personal': 2138,
#  'prejudices': 34,
#  'criticise': 32,
#  'continuing': 488,
#  'eurocentric': 3,
#  'cercle': 5,
#  'caplan': 10,
#  'sympathizers': 33,
#  'proffessed': 1,
#  'totalitarians': 1,
#  'willingness': 84,
#  'republican': 784,
#  'references': 3408,
#  'payne': 33,
#  'entered': 993,
#  'phenomena': 486,
#  'chomsky': 117,
#  'encountered': 277,
#  'inherently': 141,
#  'litist': 1,
#  'avowed': 24,
#  'ursula': 36,
#  'guin': 19,
#  'zinn': 10,
#  'alfredsson': 2,
#  'garde': 105,
#  'artist': 1106,
#  'nicol': 14,
#  'rossell': 1,
#  'freetown': 7,
#  'christiania': 13,
#  'housing': 404,
#  'crisis': 801,
#  'communes': 55,
#  'squatter': 5,
#  'thriving': 87,
#  'uprisings': 70,
#  'marxism': 186,
#  'situationist': 5,
#  'autonomist': 9,
#  'italy': 1846,
#  'punk': 323,
#  'mediums': 23,
#  'spreading': 173,
#  'exemplifies': 14,
#  'summary': 408,
#  'nihilist': 8,
#  'haymarket': 17,
#  'makhnovschina': 1,
#  'seattle': 194,
#  'rudolf': 167,
#  'rocker': 20,
#  'appleton': 26,
#  'diversity': 306,
#  'subpage': 9,
#  'anarchoblogs': 1,
#  'archives': 295,
#  'publications': 686,
#  'bleed': 36,
#  'theories': 1274,
#  'classified': 604,
#  'neurodevelopmental': 2,
#  'manifests': 36,
#  'markedly': 83,
#  'abnormal': 113,
#  'communication': 952,
#  'behavior': 1072,
#  'etiology': 25,
#  'suspect': 136,
#  'results': 1846,
#  'mediated': 56,
#  'vulnerabilities': 35,
#  'triggers': 53,
#  'tests': 544,
#  'physiologically': 9,
#  'diagnosing': 9,
#  'speculate': 83,
#  'onset': 138,
#  'incidence': 108,
#  'debated': 214,
#  'participate': 390,
#  'lingering': 29,
#  'asperger': 27,
#  'psychiatrist': 85,
#  'eugene': 315,
#  'bleuler': 6,
#  'twentieth': 483,
#  'kanner': 6,
#  'behavioral': 135,
#  'infantile': 17,
#  'suggested': 1045,
#  'autos': 9,
#  'fact': 3676,
#  'delayed': 185,
#  'tr': 158,
#  'pdd': 5,
#  'asd': 3,
#  'interactions': 287,
#  'repetitive': 65,
#  'stereotyped': 30,
#  'clinicians': 20,
#  'determining': 280,
#  'milestones': 43,
#  'determine': 805,
#  'prefers': 66,
#  'talk': 622,
#  'characteristics': 882,
#  'appropriate': 614,
#  'stimulations': 2,
#  'wildly': 64,
#  'pediatric': 25,
#  'initiate': 86,
#  'beings': 581,
#  'gaze': 22,
#  'voices': 297,
#  'grasp': 84,
#  'smile': 74,
#  'faces': 378,
#  'engage': 299,
#  'indifferent': 55,
#  'passively': 24,
#  'hugs': 12,
#  'cuddling': 4,
#  'reciprocating': 29,
#  'altogether': 229,
#  'seldom': 169,
#  'seek': 509,
#  'parents': 898,
#  'looked': 353,
#  'joys': 11,
#  'feel': 714,
#  'chimpanzees': 44,
#  'bonobos': 2,
#  'olds': 35,
#  'insights': 82,
#  'knowledge': 2154,
#  'cues': 30,
#  'facial': 102,
#  'unable': 777,
#  'predict': 212,
#  'alienation': 65,
#  'intense': 352,
#  'friends': 1176,
#  'companionship': 17,
#  'verbal': 174,
#  'outbursts': 13,
#  'negatively': 82,
#  'levels': 1487,
#  'stimulatory': 5,
#  'injury': 372,
#  'assessment': 214,
#  'coping': 22,
#  'oversensitivity': 1,
#  'underreactivity': 1,
#  'sounds': 678,
#  'clumsiness': 3,
#  'carelessness': 9,
#  'awareness': 265,
#  'distracted': 33,
#  'impulsive': 8,
#  'unwinding': 6,
#  'calming': 14,
#  'motor': 514,
#  'difficulties': 412,
#  'trouble': 275,
#  'louder': 42,
#  'filter': 314,
#  'autistics': 19,
#  'predictable': 86,
#  'babbling': 6,
#  'toddler': 6,
#  'turns': 454,
#  'distasteful': 13,
#  'paths': 185,
#  'mute': 40,
#  'signs': 651,
#  'coo': 23,
#  'babble': 4,
#  'afterwards': 501,
#  'unintelligent': 12,
#  'accommodations': 33,
#  'happily': 38,
#  'converse': 81,
#  'chat': 160,
#  'rooms': 236,
#  'websites': 263,
#  'autreat': 1,
#  'periods': 675,
#  'repeat': 200,
#  'echolalia': 2,
#  'repetitions': 21,
#  'joyous': 23,
#  'sense': 2135,
#  'precocious': 23,
#  'vocabularies': 18,
#  'conversation': 229,
#  'monologue': 25,
#  'favorite': 321,
#  'opportunity': 516,
#  'comfortably': 27,
#  'neurotypicals': 1,
#  'vocal': 344,
#  'phraseology': 11,
#  'abilities': 318,
#  'inappropriately': 18,
#  'attribute': 221,
#  'unstated': 6,
#  'auditory': 34,
#  'fluctuations': 89,
#  'robot': 244,
#  'anybody': 75,
#  'frustration': 63,
#  'grabbing': 12,
#  'socially': 182,
#  'motions': 111,
#  'stimming': 1,
#  'flapping': 18,
#  'wiggling': 3,
#  'freeze': 76,
#  'lining': 71,
#  'pretend': 19,
#  'toys': 112,
#  'upset': 138,
#  'consistency': 127,
#  'mealtimes': 2,
#  'disturbing': 56,
#  'persistent': 165,
#  'preoccupation': 32,
#  'obsessed': 53,
#  'cleaners': 17,
#  'lighthouses': 66,
#  'topics': 954,
#  'perseveration': 1,
#  'telling': 234,
#  'misinterpret': 4,
#  'instructor': 92,
#  'displaying': 102,
#  'decipher': 24,
#  'stressful': 20,
#  'presented': 920,
#  'socialization': 21,
#  'outcasts': 12,
#  'peers': 193,
#  'cope': 111,
#  'integrated': 581,
#  'classroom': 56,
#  'explain': 570,
#  'extra': 813,
#  'assist': 266,
#  'anxiety': 210,
#  'systematic': 299,
#  'approaches': 384,
#  'incredible': 109,
#  'strategies': 232,
#  'excessive': 252,
#  'items': 693,
#  'qualitative': 52,
#  'impairment': 81,
#  'manifested': 80,
#  'marked': 934,
#  'nonverbal': 11,
#  'postures': 13,
#  'pointing': 244,
#  'reciprocity': 49,
#  'impairments': 15,
#  'gesture': 77,
#  'mime': 52,
#  'sustain': 106,
#  'idiosyncratic': 43,
#  'varied': 412,
#  'imitative': 23,
#  'activities': 1201,
#  'encompassing': 90,
#  'inflexible': 20,
#  'nonfunctional': 5,
#  'mannerisms': 22,
#  'twisting': 35,
#  'accounted': 121,
#  'rett': 10,
#  'disintegrative': 4,
#  'subjective': 179,
#  'cautionary': 10,
#  'statement': 1043,
#  'methods': 1664,
#  'dysfunctional': 13,
#  'mentally': 128,
#  'handicapped': 38,
#  'mild': 276,
#  'remedied': 16,
#  'unexceptional': 2,
#  'hfa': 3,
#  'accomplish': 110,
#  'severely': 268,
#  'compromised': 60,
#  'lfa': 3,
#  'consequence': 408,
#  'underdiagnosed': 1,
#  'retardation': 46,
#  'rising': 565,
#  'diagnostics': 14,
#  'professors': 125,
#  'clinically': 34,
#  'geeks': 51,
#  'identification': 346,
#  'depicted': 461,
#  'ones': 1054,
#  'we': 6471,
#  'regressive': 7,
#  'toxin': 30,
#  'triggering': 38,
#  'mother': 2063,
#  'transfered': 9,
#  'diagnoses': 29,
#  'graph': 364,
#  'personality': 487,
#  'sudden': 246,
#  'epidemiologists': 3,
#  'reclassifications': 1,
#  'incentive': 104,
#  'federally': 25,
#  'mandated': 87,
#  'services': 2209,
#  'unconvinced': 10,
#  'chris': 378,
#  'pediatrics': 25,
#  'texas': 1018,
#  'san': 1600,
#  'antonio': 317,
#  'cochair': 1,
#  'panel': 272,
#  'newsweek': 37,
#  'ramifications': 23,
#  'vaccination': 62,
#  'societal': 61,
#  'vitro': 57,
#  'fertilization': 66,
#  'incidences': 8,
#  'geekdom': 1,
#  'hinted': 44,
#  'geek': 42,
#  'shyness': 10,
#  'profession': 199,
#  'labeled': 198,
#  'gifted': 83,
#  'clinomorphism': 1,
#  'choosing': 220,
#  'therapies': 71,
#  'facets': 46,
#  'splintered': 11,
#  'dubbed': 293,
#  'closer': 569,
#  'treated': 658,
#  'disability': 100,
#  'local': 3560,
#  'ivan': 200,
#  'charika': 1,
#  'corea': 9,
#  'charin': 1,
#  'injured': 264,
#  'tony': 475,
#  'parliamentarians': 39,
#  'palace': 760,
#  'westminster': 322,
#  'educating': 30,
#  'socializing': 12,
#  'commonalities': 8,
#  'misperception': 7,
#  'obsessions': 5,
#  'multigenerational': 2,
#  'nerds': 8,
#  'preoccupied': 23,
#  'impairs': 12,
#  'grandin': 4,
#  'courtesy': 103,
#  'nathaniel': 71,
#  'pritikin': 2,
#  'jarrold': 1,
#  'supervision': 127,
#  'managers': 207,
#  'nurturing': 15,
#  'continue': 1194,
#  'occupations': 98,
#  'offline': 37,
#  'depending': 1003,
#  'finding': 585,
#  'savants': 9,
#  'savant': 7,
#  'tammet': 1,
#  'documentary': 570,
#  'kim': 277,
#  'peek': 13,
#  'inspirations': 20,
#  'dustin': 10,
#  'splinters': 5,
#  'explores': 80,
#  'pdds': 1,
#  'specified': 459,
#  'sometime': 186,
#  'regresses': 2,
#  'responds': 93,
#  'talking': 259,
#  'wrings': 1,
#  'coordination': 147,
#  'mutation': 107,
#  'cdd': 4,
#  'chdd': 1,
#  'deteriorate': 35,
#  'behaviour': 455,
#  'regression': 82,
#  'differentiate': 118,
#  'differentiated': 81,
#  'nos': 87,
#  'subthreshold': 2,
#  'suffers': 98,
#  'guidelines': 171,
#  'comorbid': 5,
#  'aspies': 1,
#  'characters': 2418,
#  'manev': 2,
#  'aminoglycoside': 1,
#  'bmc': 2,
#  'epub': 1,
#  'strock': 1,
#  'nih': 55,
#  'institutes': 115,
#  'department': 1270,
#  'bethesda': 11,
#  'md': 190,
#  'nimh': 18,
#  'publicat': 2,
#  'cfm': 19,
#  'footnotes': 116,
#  ...}

# %%
print("oringal words: {}".format(len(vocab)))
print("update words: {}".format(len(train_words)))
# Out:
# oringal words: 240006
# update words: 228213

# %%
idx_to_word = [word for word in train_words.keys()]
word_to_index = {word:i for i, word in enumerate(idx_to_word)}
word_to_index['<unk>']
# Out:
# 228212

# %%
word_counts = np.array([count for count in train_words.values()], 
                        dtype = np.float32)

word_freqs = word_counts/ np.sum(word_counts)
word_freqs = word_freqs ** (3./4.)
word_freqs = word_counts/ np.sum(word_counts)

# %%
word_counts
# Out:
# array([5.310000e+02, 2.500000e+01, 5.400000e+01, ..., 1.000000e+00,
#        1.000000e+00, 1.506468e+07], dtype=float32)

# %%
word_freqs
# Out:
# array([3.0335827e-05, 1.4282404e-06, 3.0849992e-06, ..., 5.7129615e-08,
#        5.7129615e-08, 8.6063939e-01], dtype=float32)

# %% [markdown]
# # 构造batch

# %%
class WordEmbeddingDataset(tud.Dataset):
    def __init__(self, text, word_to_idx, idx_to_word, 
                  word_freqs, word_counts):
        super(WordEmbeddingDataset,self).__init__()
        self.text_encoded = [word_to_idx.get(word, word_to_idx['<unk>']) 
                             for word in text]
        self.text_encoded = torch.LongTensor(self.text_encoded)
        self.word_to_idx = word_to_idx
        self.idx_to_word = idx_to_word
        self.word_freqs = torch.Tensor(word_freqs)
        self.word_counts = torch.Tensor(word_counts)
    
    def __len__(self):#这个数据集一共有多少个item
        return len(self.text_encoded)
    
    def __getitem__(self, idx):#给定一个index返回一个item
        #给定一个idx返回对应中心词
        center_word = self.text_encoded[idx]
        #window内单词的index
        pos_indices = list(range(idx-c, idx)) + list(range(idx+1, idx+c+1))
        #取余数防止超出text长度
        pos_indices = [i % len(self.text_encoded) for i in pos_indices]
        pos_words = self.text_encoded[pos_indices]
        neg_words = torch.multinomial(self.word_freqs, 
                                      K*pos_words.shape[0],
                                      True)#采样方法——伯努利,依据单词的频率采样
        return center_word, pos_words, neg_words

# %%
#周围的含义
c = 3 #context window
K = 100 #number of negative samples
num_epochs = 10
batch_size = 32
learning_rate = 0.2
embedding_size = 100  #词向量维度

dataset = WordEmbeddingDataset(words, word_to_index, idx_to_word, 
                               word_freqs, word_counts)
#shuffle() 方法将序列的所有元素随机排序
dataloader = tud.DataLoader(dataset, batch_size = batch_size, shuffle = True, num_workers = 0)

# %%
for i, (center_word, pos_words, neg_words) in enumerate(dataloader):
    print(center_word, pos_words, neg_words)
    if i>5:
        break
# Out:
# tensor([ 13126, 228212, 228212, 228212,  45359, 228212, 228212, 228212, 228212,
#            878, 228212, 228212, 228212, 228212, 228212, 228212, 228212, 228212,
#          49609, 228212, 228212,      5, 213452, 228212, 228212, 228212, 228212,
#         228212, 228212,    151, 228212, 228212]) tensor([[ 13125, 228212, 228212,  13127,  11712,  13128],
#         [228212, 228212,  38971, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212,     52, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212,   2970, 228212, 228212, 228212],
#         [228212, 228212, 228212,   2070, 228212, 156849],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,   7883,   7851, 228212, 228212, 228212],
#         [  2042, 228212, 228212, 228212, 228212,  14538],
#         [228212,      5, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,   7859, 228212, 228212, 228212,   5860],
#         [228212, 228212, 228212, 157309, 228212, 228212],
#         [228212, 228212,  49909, 228212, 228212, 228212],
#         [   634, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212,      5,  13289, 228212],
#         [228212, 228212, 228212,  41961,   9315, 228212],
#         [228212,   4789, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212,  66483],
#         [228212, 228212, 228212, 116912,  34007, 228212],
#         [228212,  74840, 228212, 213453, 228212, 228212],
#         [228212, 228212, 228212,   1568, 228212, 228212],
#         [228212, 228212, 216891, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,      5,  84507, 228212, 228212,  11643],
#         [    55,    192,   5615,   1685, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [    55, 228212, 228212, 228212, 228212, 228212]]) tensor([[228212, 228212, 228212,  ..., 228212,  18411, 228212],
#         [228212, 228212, 228212,  ..., 228212, 228212, 228212],
#         [ 78502, 228212, 228212,  ..., 228212, 228212, 228212],
#         ...,
#         [228212, 228212, 228212,  ..., 228212, 228212, 228212],
#         [228212, 228212, 228212,  ..., 228212, 228212, 228212],
#         [228212, 228212, 228212,  ..., 228212, 228212, 228212]])
# tensor([228212, 228212, 228212, 228212, 228212, 228212, 228212, 228212, 228212,
#         228212, 228212, 228212, 228212, 228212, 228212, 228212, 228212, 228212,
#         228212, 228212, 228212, 228212, 228212, 228212,   2633, 228212, 228212,
#            921, 228212, 228212, 228212, 228212]) tensor([[228212, 228212, 228212,   3299,    144, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212,  82009, 228212, 228212],
#         [228212, 228212, 228212,    162, 228212, 228212],
#         [228212, 228212,  18976, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212,   1859],
#         [228212,    162, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [ 16692, 228212, 228212,  54844, 228212, 228212],
#         [228212, 228212, 228212,  11874, 228212,      5],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212,  56244, 228212, 228212, 228212],
#         [228212, 228212, 228212,    147, 228212, 228212],
#         [228212, 228212, 228212,   3245, 228212, 228212],
#         [228212, 228212, 228212,   6438, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,   9040, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212,  36030, 228212, 228212,      5],
#         [228212, 228212,   1836, 228212, 228212, 228212],
#         [228212,   3194, 228212, 228212, 228212, 228212],
#         [228212, 228212,     99, 228212, 228212, 228212],
#         [228212, 228212,      5,  46691, 228212, 228212],
#         [170109, 228212, 228212,  11900, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [ 12729, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212]]) tensor([[228212, 228212, 228212,  ..., 228212, 228212, 228212],
#         [228212,   4021, 228212,  ..., 228212, 228212, 228212],
#         [228212, 228212, 228212,  ..., 228212, 228212, 228212],
#         ...,
#         [228212, 228212, 228212,  ..., 228212,   7973,   7482],
#         [ 95366, 228212, 228212,  ..., 228212, 228212, 228212],
#         [228212, 228212, 228212,  ..., 228212, 228212, 228212]])
# tensor([228212, 228212,   4504, 228212, 228212, 228212, 228212,  26284, 228212,
#         228212, 228212, 228212, 228212, 228212, 228212, 228212, 228212, 228212,
#         228212, 228212, 228212, 228212, 228212, 228212, 228212, 228212, 228212,
#         228212, 228212,    134, 228212, 228212]) tensor([[228212,  45351,   2410, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [ 89175, 187874, 228212, 228212, 228212,   9339],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [ 61032, 210362,  23727, 228212, 228212, 228212],
#         [228212,  37996, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212,  30516],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212,  17817, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212,   9496, 228212, 228212, 228212],
#         [228212, 103358,  34490, 228212, 228212, 228212],
#         [228212, 228212,  37224,  37224, 228212, 138474],
#         [   404, 228212, 228212, 228212, 228212, 228212],
#         [141992, 228212, 228212, 228212,  27704, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [ 42731, 228212, 228212, 228212, 228212, 228212],
#         [228212,  44103, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212,   1770, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212,    581],
#         [ 61086, 228212, 121507, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,   4161, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,   6876, 228212,   2875, 228212,  11263],
#         [228212,    386, 228212, 228212, 197968, 162817],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [ 59712, 228212,  63474, 228212,   1685, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,  25147, 228212, 228212,  21200,  66289]]) tensor([[228212, 228212, 228212,  ..., 228212, 228212, 228212],
#         [228212, 228212, 228212,  ...,   1461, 228212, 228212],
#         [228212,     76, 228212,  ..., 228212, 228212, 228212],
#         ...,
#         [228212,    309, 228212,  ..., 228212, 228212, 228212],
#         [228212, 228212, 228212,  ..., 228212, 228212, 228212],
#         [228212, 228212, 228212,  ...,   1014,  11740, 228212]])
# tensor([228212, 228212,  53587, 228212, 228212, 228212, 228212, 228212, 228212,
#         228212, 228212,   3737, 228212, 228212, 228212, 228212,     74, 228212,
#         171859, 228212, 228212, 228212, 228212, 228212, 228212, 228212,      5,
#         228212, 228212, 228212, 228212, 228212]) tensor([[228212, 228212, 228212, 228212, 228212,  85610],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212,  28871, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212,    760, 228212,   9021],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212,   3728],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,   1153, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [ 25949, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212,    449, 228212],
#         [228212, 228212,     91, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212,  11651, 228212],
#         [228212, 228212,  14671, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 157071, 157910],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [   282, 228212, 228212, 228212, 228212, 228212],
#         [  1839, 228212, 228212, 228212,   1840, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,   1836,   3211, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,   1007,  40909, 228212,   6270, 228212],
#         [228212,  95978, 228212, 228212, 228212, 228212],
#         [228212,  32638, 228212,   5313, 228212, 228212],
#         [228212, 228212, 228212, 228212,    993, 228212],
#         [  6741,  82359,    349, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,   4169, 228212, 228212, 228212,   9851],
#         [228212, 228212, 228212, 228212, 228212, 228212]]) tensor([[  5921, 171960, 228212,  ..., 228212, 228212, 228212],
#         [228212, 228212,  83726,  ..., 228212, 228212, 228212],
#         [  4075, 228212, 228212,  ...,   1554, 228212, 228212],
#         ...,
#         [228212, 228212, 228212,  ..., 228212, 228212, 228212],
#         [228212, 228212, 228212,  ...,     42,    528, 228212],
#         [228212, 228212, 228212,  ..., 228212, 228212, 228212]])
# tensor([  4306, 228212, 228212, 228212, 228212, 228212, 228212, 141542, 228212,
#         228212, 228212,   3217, 228212,   3857, 228212,   1932, 228212, 228212,
#         228212, 228212, 228212, 228212, 228212, 228212, 228212, 228212, 228212,
#         228212, 228212, 228212, 228212, 156990]) tensor([[228212, 228212, 228212, 228212, 228212,  94506],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,   4607, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212,  21200, 228212],
#         [203329,      5, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 141543, 228212],
#         [228212, 228212, 228212,      5, 228212, 228212],
#         [228212, 228212, 228212, 228212,   3435, 228212],
#         [228212, 228212, 228212, 228212,  13368, 228212],
#         [     5, 228212,  25458,    147, 228212,   2306],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,   3108, 228212, 228212, 228212, 228212],
#         [228212,   5738, 228212, 228212,   5737, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [ 11238, 228212, 228212,  14191, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [ 34846, 228212,  34847, 228212, 228212, 228212],
#         [228212, 228212, 228212,  59494, 228212,   2151],
#         [228212,  13978, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212,   1492, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212,  20548, 228212,  42102,  61635],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212,  43702, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212,   1006, 228212]]) tensor([[228212, 228212,  21376,  ..., 228212,  48746, 228212],
#         [228212, 228212, 228212,  ...,  11231, 228212, 228212],
#         [228212, 228212, 228212,  ..., 228212, 228212, 228212],
#         ...,
#         [ 56289, 228212, 228212,  ..., 228212, 228212, 228212],
#         [  3365, 228212, 228212,  ..., 228212, 228212, 228212],
#         [228212,   8506, 228212,  ..., 228212, 228212, 228212]])
# tensor([228212, 228212, 228212,    477,   3325, 228212, 228212, 228212, 228212,
#         228212, 228212, 228212, 228212, 228212,   2543, 228212, 228212, 228212,
#         228212, 228212, 228212, 227990, 228212,  38493,    995,    162, 228212,
#         228212, 228212, 228212, 228212, 228212]) tensor([[228212, 228212, 228212, 228212, 228212,     76],
#         [228212,   5049, 228212, 228212, 228212, 228212],
#         [228212, 228212,     74,   7675, 228212, 228212],
#         [228212, 228212,  26822, 228212, 228212, 228212],
#         [104944, 228212, 228212, 228212, 228212, 228212],
#         [114540,   1063, 228212,  20405,  24913,   1063],
#         [228212, 228212, 228212, 228212, 228212,   7569],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212,   7500],
#         [228212, 228212, 228212,    163, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,  35090, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212,   7835, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,   2729, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212,  59877, 228212,   2278, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 227989, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212,    334, 228212],
#         [228212,    995, 228212, 228212,   6274, 228212],
#         [   544,  17102, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [ 19370, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212,    301, 228212],
#         [228212,  52797, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212]]) tensor([[228212, 228212, 228212,  ..., 228212, 228212, 228212],
#         [228212,  14425, 228212,  ..., 228212, 228212, 228212],
#         [228212, 228212, 228212,  ..., 228212, 228212, 228212],
#         ...,
#         [228212,   3435, 228212,  ..., 228212, 228212, 228212],
#         [    51, 228212, 228212,  ..., 228212,  22450,  16784],
#         [   580,   4258, 228212,  ..., 228212, 228212, 228212]])
# tensor([228212,  47309, 228212, 228212, 228212, 228212, 228212, 228212, 228212,
#         228212,  24224, 228212, 228212, 228212,    624, 228212, 228212, 228212,
#         228212, 228212, 228212, 228212, 228212, 228212, 228212, 228212, 228212,
#         228212, 228212, 228212, 228212, 228212]) tensor([[228212, 228212, 228212, 228212, 228212,   2792],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212,  49229, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212,  52865, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212,  11720],
#         [228212, 228212, 228212, 228212,   1376, 228212],
#         [   329, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [ 38900,  24438, 228212, 228212,   4846, 128281],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212,   4132, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212,  41890, 228212],
#         [ 22128, 228212, 228212, 228212,  12569, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [ 97441,  47366, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [  1161, 228212, 228212, 228212,   5262, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212, 228212, 228212, 228212],
#         [   395, 228212, 228212, 228212, 228212, 228212],
#         [228212, 228212, 228212,  14181,  86024, 228212]]) tensor([[   926, 228212,    529,  ..., 228212, 228212, 228212],
#         [228212, 228212, 228212,  ...,   8937,  22205, 228212],
#         [228212,   9544, 228212,  ..., 228212, 228212, 228212],
#         ...,
#         [228212, 228212, 228212,  ...,    134, 228212, 228212],
#         [228212, 228212, 228212,  ..., 228212, 228212, 228212],
#         [228212, 228212,     10,  ..., 228212, 228212, 228212]])

# %% [markdown]
# # 构建模型

# %%
class EmbeddingModel(nn.Module):
    def __init__(self, vocab_size, embed_size):
        ''' 初始化输出和输出embedding
        '''
        super(EmbeddingModel, self).__init__()
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        
        initrange = 0.5 / self.embed_size
        self.out_embed = nn.Embedding(self.vocab_size, self.embed_size, sparse=False)
        self.out_embed.weight.data.uniform_(-initrange, initrange)
        
        
        self.in_embed = nn.Embedding(self.vocab_size, self.embed_size, sparse=False)
        self.in_embed.weight.data.uniform_(-initrange, initrange)
        
        
    def forward(self, input_labels, pos_labels, neg_labels):
        '''
        input_labels: 中心词, [batch_size]
        pos_labels: 中心词周围 context window 出现过的单词 [batch_size * (window_size * 2)]
        neg_labelss: 中心词周围没有出现过的单词，从 negative sampling 得到 [batch_size, (window_size * 2 * K)]
        
        return: loss, [batch_size]
        '''
        
        batch_size = input_labels.size(0)
        
        input_embedding = self.in_embed(input_labels) # B * embed_size
        pos_embedding = self.out_embed(pos_labels) # B * (2*C) * embed_size
        neg_embedding = self.out_embed(neg_labels) # B * (2*C * K) * embed_size
      
        log_pos = torch.bmm(pos_embedding, input_embedding.unsqueeze(2)).squeeze() # B * (2*C)
        log_neg = torch.bmm(neg_embedding, -input_embedding.unsqueeze(2)).squeeze() # B * (2*C*K)

        log_pos = F.logsigmoid(log_pos).sum(1)
        log_neg = F.logsigmoid(log_neg).sum(1) # batch_size
       
        loss = log_pos + log_neg
        
        return -loss
    
    def input_embeddings(self):
        return self.in_embed.weight.data.cpu().numpy()

# %% [markdown]
# model.input_embeddings() 是我们最终需要的embedding！

# %% [markdown]
# # 模型训练

# %%
vocab_size = len(idx_to_word)

# %%
SEED = 1234

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model = EmbeddingModel(vocab_size, embedding_size)
model = model.to(device)
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)

# %%
model
# Out:
# EmbeddingModel(
#   (out_embed): Embedding(228213, 100)
#   (in_embed): Embedding(228213, 100)
# )

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
count_parameters(model)
# Out:
# 45642600

# %% [markdown]
# 评估两个单词的相似性

# %%
def evaluate(filename, embedding_weights): 
    if filename.endswith(".csv"):
        data = pd.read_csv(filename, sep=",")
    else:
        data = pd.read_csv(filename, sep="\t")
    human_similarity = []
    model_similarity = []
    for i in data.iloc[:, 0:2].index:
        word1, word2 = data.iloc[i, 0], data.iloc[i, 1]
        if word1 not in word_to_idx or word2 not in word_to_idx:
            continue
        else:
            word1_idx, word2_idx = word_to_idx[word1], word_to_idx[word2]
            word1_embed, word2_embed = embedding_weights[[word1_idx]], embedding_weights[[word2_idx]]
            model_similarity.append(float(sklearn.metrics.pairwise.cosine_similarity(word1_embed, word2_embed)))
            human_similarity.append(float(data.iloc[i, 2]))

    return scipy.stats.spearmanr(human_similarity, model_similarity)# , model_similarity

# %% [markdown]
# 寻找到与word最接近的10个单词

# %%
def find_nearest(word):
    index = word_to_idx[word]
    embedding = embedding_weights[index]
    cos_dis = np.array([scipy.spatial.distance.cosine(e, embedding) for e in embedding_weights])
    return [idx_to_word[i] for i in cos_dis.argsort()[:10]]

# %%
for e in range(num_epochs):
    for i, (input_labels, pos_labels, neg_labels) in enumerate(dataloader):
        
        input_labels = input_labels.long().to(device)
        pos_labels = pos_labels.long().to(device)
        neg_labels = neg_labels.long().to(device)
            
        optimizer.zero_grad()
        loss = model(input_labels, pos_labels, neg_labels).mean()
        loss.backward()
        optimizer.step()

        if i % 100 == 0:
            with open(LOG_FILE, "a") as fout:
                fout.write("epoch: {}, iter: {}, loss: {}\n".format(e, i, loss.item()))
                print("epoch: {}, iter: {}, loss: {}".format(e, i, loss.item()))
            
        
        if i % 2000 == 0:
            embedding_weights = model.input_embeddings()
            sim_simlex = evaluate("simlex-999.txt", embedding_weights)
            sim_men = evaluate("men.txt", embedding_weights)
            sim_353 = evaluate("wordsim353.csv", embedding_weights)
            with open(LOG_FILE, "a") as fout:
                print("epoch: {}, iteration: {}, simlex-999: {}, men: {}, sim353: {}, nearest to monster: {}\n".format(
                    e, i, sim_simlex, sim_men, sim_353, find_nearest("monster")))
                fout.write("epoch: {}, iteration: {}, simlex-999: {}, men: {}, sim353: {}, nearest to monster: {}\n".format(
                    e, i, sim_simlex, sim_men, sim_353, find_nearest("monster")))
                
    embedding_weights = model.input_embeddings()
    np.save("embedding-{}".format(embedding_size), embedding_weights)
    torch.save(model.state_dict(), "embedding-{}.th".format(embedding_size))
